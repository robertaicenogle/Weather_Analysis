# %%
# Import Dependencies .
import pandas as pd 
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests
import time

# %%
# Create an empty list for weather data.
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bdcd2f4e896bc3ba596f00fee7f607e1

# %%
# Create 2000 random latitude and longitude coordinates 
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(latitudes, longitudes)
coordinates

# %%
# Add coordinates to a list.
coordinates_lst = list(coordinates)

# %%
# Create a list for cities.
cities = []

# Use citipy to find nearest cities using coordinate list.
for coordinate in coordinates_lst:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)

# Count amount of unique cities
len(cities)
# Out:
# 743

# %%
# Loop through all the cities in the list. 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | tasiilaq
# Processing Record 2 of Set 1 | port elizabeth
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | ust-nera
# Processing Record 6 of Set 1 | klaksvik
# Processing Record 7 of Set 1 | haines junction
# Processing Record 8 of Set 1 | yellowknife
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | sunndalsora
# Processing Record 11 of Set 1 | zhigansk
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | richards bay
# Processing Record 14 of Set 1 | ahipara
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | batemans bay
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | lianzhou
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | longlac
# City not found. Skipping...
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | thompson
# Processing Record 23 of Set 1 | salto de agua
# Processing Record 24 of Set 1 | vila
# Processing Record 25 of Set 1 | lata
# Processing Record 26 of Set 1 | acarau
# Processing Record 27 of Set 1 | mergui
# City not found. Skipping...
# Processing Record 28 of Set 1 | portland
# Processing Record 29 of Set 1 | warrnambool
# Processing Record 30 of Set 1 | ushtobe
# Processing Record 31 of Set 1 | navrongo
# Processing Record 32 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 1 | mar del plata
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 1 | qaanaaq
# Processing Record 37 of Set 1 | upernavik
# Processing Record 38 of Set 1 | lompoc
# Processing Record 39 of Set 1 | sept-iles
# Processing Record 40 of Set 1 | coquimbo
# Processing Record 41 of Set 1 | sawtell
# Processing Record 42 of Set 1 | panzhihua
# Processing Record 43 of Set 1 | yabelo
# Processing Record 44 of Set 1 | aklavik
# Processing Record 45 of Set 1 | meridian
# Processing Record 46 of Set 1 | tuktoyaktuk
# Processing Record 47 of Set 1 | nikolskoye
# Processing Record 48 of Set 1 | touros
# Processing Record 49 of Set 1 | satitoa
# City not found. Skipping...
# Processing Record 50 of Set 1 | atuona
# Processing Record 1 of Set 2 | vostok
# Processing Record 2 of Set 2 | sorso
# Processing Record 3 of Set 2 | conde
# Processing Record 4 of Set 2 | ilulissat
# Processing Record 5 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 2 | half moon bay
# Processing Record 7 of Set 2 | victoria
# Processing Record 8 of Set 2 | nome
# Processing Record 9 of Set 2 | hithadhoo
# Processing Record 10 of Set 2 | rikitea
# Processing Record 11 of Set 2 | bafra
# Processing Record 12 of Set 2 | dunedin
# Processing Record 13 of Set 2 | port keats
# Processing Record 14 of Set 2 | nemuro
# Processing Record 15 of Set 2 | ribeira grande
# Processing Record 16 of Set 2 | green valley
# Processing Record 17 of Set 2 | virginia beach
# Processing Record 18 of Set 2 | bowen
# Processing Record 19 of Set 2 | puerto ayora
# Processing Record 20 of Set 2 | moron
# Processing Record 21 of Set 2 | koutiala
# Processing Record 22 of Set 2 | kapaa
# Processing Record 23 of Set 2 | fort-de-france
# Processing Record 24 of Set 2 | christchurch
# Processing Record 25 of Set 2 | umm durman
# City not found. Skipping...
# Processing Record 26 of Set 2 | tessalit
# Processing Record 27 of Set 2 | ponta do sol
# Processing Record 28 of Set 2 | airai
# Processing Record 29 of Set 2 | bulungu
# Processing Record 30 of Set 2 | kodiak
# Processing Record 31 of Set 2 | mayo
# Processing Record 32 of Set 2 | meulaboh
# Processing Record 33 of Set 2 | zinder
# Processing Record 34 of Set 2 | agsu
# City not found. Skipping...
# Processing Record 35 of Set 2 | lorengau
# Processing Record 36 of Set 2 | hobart
# Processing Record 37 of Set 2 | kavieng
# Processing Record 38 of Set 2 | odda
# Processing Record 39 of Set 2 | dandeli
# Processing Record 40 of Set 2 | ampanihy
# Processing Record 41 of Set 2 | provideniya
# Processing Record 42 of Set 2 | esperance
# Processing Record 43 of Set 2 | vaini
# Processing Record 44 of Set 2 | boden
# Processing Record 45 of Set 2 | sobolevo
# Processing Record 46 of Set 2 | bethel
# Processing Record 47 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 48 of Set 2 | saint-joseph
# Processing Record 49 of Set 2 | tir pol
# City not found. Skipping...
# Processing Record 50 of Set 2 | yakeshi
# Processing Record 1 of Set 3 | tuatapere
# Processing Record 2 of Set 3 | labuhan
# Processing Record 3 of Set 3 | faanui
# Processing Record 4 of Set 3 | butaritari
# Processing Record 5 of Set 3 | clyde river
# Processing Record 6 of Set 3 | dinajpur
# Processing Record 7 of Set 3 | bagotville
# Processing Record 8 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 3 | vitim
# Processing Record 10 of Set 3 | mataura
# Processing Record 11 of Set 3 | kuldur
# Processing Record 12 of Set 3 | torbay
# Processing Record 13 of Set 3 | sisimiut
# Processing Record 14 of Set 3 | port blair
# Processing Record 15 of Set 3 | ailigandi
# Processing Record 16 of Set 3 | isangel
# Processing Record 17 of Set 3 | yar-sale
# Processing Record 18 of Set 3 | asau
# Processing Record 19 of Set 3 | khatanga
# Processing Record 20 of Set 3 | deori
# Processing Record 21 of Set 3 | makaha
# Processing Record 22 of Set 3 | bo
# City not found. Skipping...
# Processing Record 23 of Set 3 | shenjiamen
# Processing Record 24 of Set 3 | jamestown
# Processing Record 25 of Set 3 | berlevag
# Processing Record 26 of Set 3 | gorin
# Processing Record 27 of Set 3 | arraial do cabo
# Processing Record 28 of Set 3 | te anau
# Processing Record 29 of Set 3 | liverpool
# Processing Record 30 of Set 3 | sur
# Processing Record 31 of Set 3 | port augusta
# Processing Record 32 of Set 3 | bontang
# Processing Record 33 of Set 3 | diyarb najm
# Processing Record 34 of Set 3 | vallenar
# Processing Record 35 of Set 3 | saint-ambroise
# Processing Record 36 of Set 3 | great yarmouth
# Processing Record 37 of Set 3 | ranong
# Processing Record 38 of Set 3 | korla
# Processing Record 39 of Set 3 | severo-kurilsk
# Processing Record 40 of Set 3 | linxia
# Processing Record 41 of Set 3 | sangar
# Processing Record 42 of Set 3 | kamenka
# Processing Record 43 of Set 3 | hay river
# Processing Record 44 of Set 3 | goleta
# Processing Record 45 of Set 3 | hualmay
# Processing Record 46 of Set 3 | san quintin
# Processing Record 47 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 48 of Set 3 | talnakh
# Processing Record 49 of Set 3 | khormuj
# City not found. Skipping...
# Processing Record 50 of Set 3 | axim
# Processing Record 1 of Set 4 | ayorou
# Processing Record 2 of Set 4 | avarua
# Processing Record 3 of Set 4 | xining
# Processing Record 4 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 4 | pundaguitan
# Processing Record 6 of Set 4 | palmer
# Processing Record 7 of Set 4 | bambous virieux
# Processing Record 8 of Set 4 | zhangye
# Processing Record 9 of Set 4 | siocon
# Processing Record 10 of Set 4 | hisar
# Processing Record 11 of Set 4 | cabedelo
# Processing Record 12 of Set 4 | castro
# Processing Record 13 of Set 4 | tome
# Processing Record 14 of Set 4 | manono
# Processing Record 15 of Set 4 | mbandaka
# Processing Record 16 of Set 4 | estelle
# Processing Record 17 of Set 4 | bubaque
# Processing Record 18 of Set 4 | ferrol
# Processing Record 19 of Set 4 | dingle
# Processing Record 20 of Set 4 | longyearbyen
# Processing Record 21 of Set 4 | pevek
# Processing Record 22 of Set 4 | pahuatlan
# City not found. Skipping...
# Processing Record 23 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 24 of Set 4 | opuwo
# Processing Record 25 of Set 4 | sitka
# Processing Record 26 of Set 4 | geraldton
# Processing Record 27 of Set 4 | tupik
# Processing Record 28 of Set 4 | yaan
# Processing Record 29 of Set 4 | vila do maio
# Processing Record 30 of Set 4 | puerto madero
# Processing Record 31 of Set 4 | auki
# Processing Record 32 of Set 4 | neepawa
# Processing Record 33 of Set 4 | new norfolk
# Processing Record 34 of Set 4 | makakilo city
# Processing Record 35 of Set 4 | kashi
# Processing Record 36 of Set 4 | fairbanks
# Processing Record 37 of Set 4 | cape town
# Processing Record 38 of Set 4 | grindavik
# Processing Record 39 of Set 4 | lebu
# Processing Record 40 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 4 | guerrero negro
# Processing Record 42 of Set 4 | buala
# Processing Record 43 of Set 4 | tilichiki
# Processing Record 44 of Set 4 | san cristobal
# Processing Record 45 of Set 4 | bozuyuk
# Processing Record 46 of Set 4 | otane
# Processing Record 47 of Set 4 | eyl
# Processing Record 48 of Set 4 | kruisfontein
# Processing Record 49 of Set 4 | bastrop
# Processing Record 50 of Set 4 | port alfred
# Processing Record 1 of Set 5 | arlit
# Processing Record 2 of Set 5 | colwyn bay
# Processing Record 3 of Set 5 | mikhaylovka
# Processing Record 4 of Set 5 | cravo norte
# Processing Record 5 of Set 5 | chapais
# Processing Record 6 of Set 5 | nigde
# Processing Record 7 of Set 5 | kaitangata
# Processing Record 8 of Set 5 | benghazi
# Processing Record 9 of Set 5 | east london
# Processing Record 10 of Set 5 | bismarck
# Processing Record 11 of Set 5 | mirnyy
# Processing Record 12 of Set 5 | mankapur
# Processing Record 13 of Set 5 | saint-augustin
# Processing Record 14 of Set 5 | wladyslawowo
# Processing Record 15 of Set 5 | rotterdam
# Processing Record 16 of Set 5 | kamaishi
# Processing Record 17 of Set 5 | we
# City not found. Skipping...
# Processing Record 18 of Set 5 | saint george
# Processing Record 19 of Set 5 | codrington
# Processing Record 20 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 5 | rocha
# Processing Record 23 of Set 5 | chaozhou
# Processing Record 24 of Set 5 | kaka
# Processing Record 25 of Set 5 | ancud
# Processing Record 26 of Set 5 | otavi
# Processing Record 27 of Set 5 | buy
# Processing Record 28 of Set 5 | belaya gora
# Processing Record 29 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 5 | balanacan
# Processing Record 31 of Set 5 | muzaffarnagar
# Processing Record 32 of Set 5 | santa cruz de la palma
# Processing Record 33 of Set 5 | saint-philippe
# Processing Record 34 of Set 5 | jiujiang
# Processing Record 35 of Set 5 | vangaindrano
# Processing Record 36 of Set 5 | ravar
# Processing Record 37 of Set 5 | dong hoi
# Processing Record 38 of Set 5 | tarakan
# Processing Record 39 of Set 5 | verkhoyansk
# Processing Record 40 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 5 | hamilton
# Processing Record 42 of Set 5 | champerico
# Processing Record 43 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 5 | teguise
# Processing Record 45 of Set 5 | rio grande
# Processing Record 46 of Set 5 | praia da vitoria
# Processing Record 47 of Set 5 | high level
# Processing Record 48 of Set 5 | saldanha
# Processing Record 49 of Set 5 | paredon
# Processing Record 50 of Set 5 | mabaruma
# Processing Record 1 of Set 6 | launceston
# Processing Record 2 of Set 6 | odweyne
# Processing Record 3 of Set 6 | teya
# Processing Record 4 of Set 6 | sambava
# Processing Record 5 of Set 6 | solano
# Processing Record 6 of Set 6 | goalpara
# Processing Record 7 of Set 6 | swan hill
# Processing Record 8 of Set 6 | muhos
# Processing Record 9 of Set 6 | olga
# Processing Record 10 of Set 6 | laguna
# Processing Record 11 of Set 6 | oranjemund
# Processing Record 12 of Set 6 | hilo
# Processing Record 13 of Set 6 | kloulklubed
# Processing Record 14 of Set 6 | kawalu
# Processing Record 15 of Set 6 | turukhansk
# Processing Record 16 of Set 6 | egvekinot
# Processing Record 17 of Set 6 | bengkulu
# Processing Record 18 of Set 6 | buqayq
# City not found. Skipping...
# Processing Record 19 of Set 6 | gisors
# Processing Record 20 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 21 of Set 6 | itamaraca
# Processing Record 22 of Set 6 | nishihara
# Processing Record 23 of Set 6 | eydhafushi
# Processing Record 24 of Set 6 | khipro
# Processing Record 25 of Set 6 | beringovskiy
# Processing Record 26 of Set 6 | anadyr
# Processing Record 27 of Set 6 | havre-saint-pierre
# Processing Record 28 of Set 6 | araouane
# Processing Record 29 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 6 | okha
# Processing Record 31 of Set 6 | hasaki
# Processing Record 32 of Set 6 | vardo
# Processing Record 33 of Set 6 | cuiluan
# Processing Record 34 of Set 6 | itaituba
# Processing Record 35 of Set 6 | chokurdakh
# Processing Record 36 of Set 6 | san andres
# Processing Record 37 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 38 of Set 6 | yining
# Processing Record 39 of Set 6 | georgetown
# Processing Record 40 of Set 6 | bayji
# Processing Record 41 of Set 6 | karlskrona
# Processing Record 42 of Set 6 | sao francisco do sul
# Processing Record 43 of Set 6 | yamada
# Processing Record 44 of Set 6 | baiyin
# Processing Record 45 of Set 6 | carnarvon
# Processing Record 46 of Set 6 | san patricio
# Processing Record 47 of Set 6 | boa vista
# Processing Record 48 of Set 6 | rio gallegos
# Processing Record 49 of Set 6 | cidreira
# Processing Record 50 of Set 6 | saskylakh
# Processing Record 1 of Set 7 | macklin
# Processing Record 2 of Set 7 | skagastrond
# City not found. Skipping...
# Processing Record 3 of Set 7 | magadan
# Processing Record 4 of Set 7 | shimoda
# Processing Record 5 of Set 7 | broken hill
# Processing Record 6 of Set 7 | taltal
# Processing Record 7 of Set 7 | constitucion
# Processing Record 8 of Set 7 | vichy
# Processing Record 9 of Set 7 | ostrovnoy
# Processing Record 10 of Set 7 | san marcos
# Processing Record 11 of Set 7 | pisco
# Processing Record 12 of Set 7 | wenling
# Processing Record 13 of Set 7 | ob
# City not found. Skipping...
# Processing Record 14 of Set 7 | kaeo
# Processing Record 15 of Set 7 | carlyle
# Processing Record 16 of Set 7 | san fernando
# Processing Record 17 of Set 7 | zambezi
# Processing Record 18 of Set 7 | governador valadares
# Processing Record 19 of Set 7 | rawson
# Processing Record 20 of Set 7 | los llanos de aridane
# Processing Record 21 of Set 7 | chake chake
# Processing Record 22 of Set 7 | kundiawa
# Processing Record 23 of Set 7 | komsomolskiy
# Processing Record 24 of Set 7 | katsuura
# Processing Record 25 of Set 7 | port hedland
# Processing Record 26 of Set 7 | pujili
# Processing Record 27 of Set 7 | khovu-aksy
# Processing Record 28 of Set 7 | sao gabriel da cachoeira
# Processing Record 29 of Set 7 | mlonggo
# Processing Record 30 of Set 7 | iqaluit
# Processing Record 31 of Set 7 | acajutla
# Processing Record 32 of Set 7 | jumla
# Processing Record 33 of Set 7 | jos
# Processing Record 34 of Set 7 | naze
# Processing Record 35 of Set 7 | ramachandrapuram
# Processing Record 36 of Set 7 | boende
# Processing Record 37 of Set 7 | gaptsakh
# Processing Record 38 of Set 7 | dongsheng
# Processing Record 39 of Set 7 | jaisalmer
# Processing Record 40 of Set 7 | emilio carranza
# Processing Record 41 of Set 7 | sorland
# Processing Record 42 of Set 7 | tashla
# Processing Record 43 of Set 7 | beaverlodge
# Processing Record 44 of Set 7 | ixtapa
# Processing Record 45 of Set 7 | fort nelson
# Processing Record 46 of Set 7 | bondoukou
# Processing Record 47 of Set 7 | pocone
# Processing Record 48 of Set 7 | maloyaroslavets
# Processing Record 49 of Set 7 | mandera
# Processing Record 50 of Set 7 | mantua
# Processing Record 1 of Set 8 | plainview
# Processing Record 2 of Set 8 | nanortalik
# Processing Record 3 of Set 8 | chuy
# Processing Record 4 of Set 8 | langham
# Processing Record 5 of Set 8 | lavrentiya
# Processing Record 6 of Set 8 | mahebourg
# Processing Record 7 of Set 8 | gazion
# City not found. Skipping...
# Processing Record 8 of Set 8 | kismayo
# Processing Record 9 of Set 8 | atherton
# Processing Record 10 of Set 8 | la ronge
# Processing Record 11 of Set 8 | topolobampo
# Processing Record 12 of Set 8 | jacmel
# Processing Record 13 of Set 8 | magaria
# Processing Record 14 of Set 8 | matara
# Processing Record 15 of Set 8 | antibes
# Processing Record 16 of Set 8 | port hardy
# Processing Record 17 of Set 8 | henties bay
# Processing Record 18 of Set 8 | namie
# Processing Record 19 of Set 8 | pavlovsk
# Processing Record 20 of Set 8 | broome
# Processing Record 21 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 8 | norman wells
# Processing Record 23 of Set 8 | xichang
# Processing Record 24 of Set 8 | harper
# Processing Record 25 of Set 8 | saravan
# Processing Record 26 of Set 8 | olinda
# Processing Record 27 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 8 | bolshoy uluy
# City not found. Skipping...
# Processing Record 29 of Set 8 | muli
# Processing Record 30 of Set 8 | khatima
# Processing Record 31 of Set 8 | vila franca do campo
# Processing Record 32 of Set 8 | jahazpur
# Processing Record 33 of Set 8 | totma
# Processing Record 34 of Set 8 | lagoa
# Processing Record 35 of Set 8 | stromness
# Processing Record 36 of Set 8 | houma
# Processing Record 37 of Set 8 | srednekolymsk
# Processing Record 38 of Set 8 | kalianget
# Processing Record 39 of Set 8 | alyangula
# Processing Record 40 of Set 8 | santa isabel
# Processing Record 41 of Set 8 | inongo
# Processing Record 42 of Set 8 | angoche
# Processing Record 43 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 44 of Set 8 | myitkyina
# Processing Record 45 of Set 8 | pochutla
# Processing Record 46 of Set 8 | suez
# Processing Record 47 of Set 8 | kargil
# Processing Record 48 of Set 8 | barmer
# Processing Record 49 of Set 8 | sabang
# Processing Record 50 of Set 8 | severo-yeniseyskiy
# Processing Record 1 of Set 9 | tiksi
# Processing Record 2 of Set 9 | narsaq
# Processing Record 3 of Set 9 | namatanai
# Processing Record 4 of Set 9 | yozgat
# Processing Record 5 of Set 9 | northam
# Processing Record 6 of Set 9 | smithers
# Processing Record 7 of Set 9 | gualaca
# Processing Record 8 of Set 9 | fortuna
# Processing Record 9 of Set 9 | notse
# Processing Record 10 of Set 9 | macaboboni
# City not found. Skipping...
# Processing Record 11 of Set 9 | taber
# Processing Record 12 of Set 9 | arica
# Processing Record 13 of Set 9 | atambua
# Processing Record 14 of Set 9 | panshi
# Processing Record 15 of Set 9 | shelburne
# Processing Record 16 of Set 9 | bereda
# Processing Record 17 of Set 9 | catia la mar
# Processing Record 18 of Set 9 | olafsvik
# Processing Record 19 of Set 9 | kutum
# Processing Record 20 of Set 9 | san borja
# Processing Record 21 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 22 of Set 9 | paragould
# Processing Record 23 of Set 9 | dikson
# Processing Record 24 of Set 9 | faya
# Processing Record 25 of Set 9 | husavik
# Processing Record 26 of Set 9 | takoradi
# Processing Record 27 of Set 9 | tongling
# Processing Record 28 of Set 9 | shevchenko
# Processing Record 29 of Set 9 | freeport
# Processing Record 30 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 31 of Set 9 | hofn
# Processing Record 32 of Set 9 | kushima
# Processing Record 33 of Set 9 | bathsheba
# Processing Record 34 of Set 9 | wadi maliz
# Processing Record 35 of Set 9 | pontes e lacerda
# Processing Record 36 of Set 9 | novouzensk
# Processing Record 37 of Set 9 | trenggalek
# Processing Record 38 of Set 9 | mount gambier
# Processing Record 39 of Set 9 | salinopolis
# Processing Record 40 of Set 9 | alofi
# Processing Record 41 of Set 9 | ust-maya
# Processing Record 42 of Set 9 | tezu
# Processing Record 43 of Set 9 | gidole
# Processing Record 44 of Set 9 | kysyl-syr
# Processing Record 45 of Set 9 | daru
# Processing Record 46 of Set 9 | pakaur
# Processing Record 47 of Set 9 | sioux lookout
# Processing Record 48 of Set 9 | seminole
# Processing Record 49 of Set 9 | caluquembe
# Processing Record 50 of Set 9 | padang
# Processing Record 1 of Set 10 | santa marta
# Processing Record 2 of Set 10 | yenagoa
# Processing Record 3 of Set 10 | pecos
# Processing Record 4 of Set 10 | isernia
# Processing Record 5 of Set 10 | dandong
# Processing Record 6 of Set 10 | amga
# Processing Record 7 of Set 10 | tripoli
# Processing Record 8 of Set 10 | port-gentil
# Processing Record 9 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 10 of Set 10 | corbelia
# Processing Record 11 of Set 10 | itacoatiara
# Processing Record 12 of Set 10 | kuusamo
# Processing Record 13 of Set 10 | taldan
# Processing Record 14 of Set 10 | acapulco
# Processing Record 15 of Set 10 | bandarbeyla
# Processing Record 16 of Set 10 | biltine
# Processing Record 17 of Set 10 | phuntsholing
# Processing Record 18 of Set 10 | parabel
# Processing Record 19 of Set 10 | sao filipe
# Processing Record 20 of Set 10 | phulji
# Processing Record 21 of Set 10 | pinotepa nacional
# Processing Record 22 of Set 10 | samarai
# Processing Record 23 of Set 10 | natal
# Processing Record 24 of Set 10 | flinders
# Processing Record 25 of Set 10 | bilibino
# Processing Record 26 of Set 10 | killam
# Processing Record 27 of Set 10 | pavino
# Processing Record 28 of Set 10 | iquique
# Processing Record 29 of Set 10 | payo
# Processing Record 30 of Set 10 | lishan
# Processing Record 31 of Set 10 | port hueneme
# Processing Record 32 of Set 10 | belmonte
# Processing Record 33 of Set 10 | ibanda
# Processing Record 34 of Set 10 | woodward
# Processing Record 35 of Set 10 | kamphaeng phet
# Processing Record 36 of Set 10 | barzas
# Processing Record 37 of Set 10 | luderitz
# Processing Record 38 of Set 10 | wanaka
# Processing Record 39 of Set 10 | bairiki
# Processing Record 40 of Set 10 | palkaka
# City not found. Skipping...
# Processing Record 41 of Set 10 | manokwari
# Processing Record 42 of Set 10 | clarence town
# Processing Record 43 of Set 10 | usevya
# Processing Record 44 of Set 10 | vestmannaeyjar
# Processing Record 45 of Set 10 | westport
# Processing Record 46 of Set 10 | altamont
# Processing Record 47 of Set 10 | grand gaube
# Processing Record 48 of Set 10 | rodrigues alves
# Processing Record 49 of Set 10 | lowestoft
# Processing Record 50 of Set 10 | peterhead
# Processing Record 1 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 2 of Set 11 | eldorado
# Processing Record 3 of Set 11 | katha
# City not found. Skipping...
# Processing Record 4 of Set 11 | nehe
# Processing Record 5 of Set 11 | coruripe
# Processing Record 6 of Set 11 | bourail
# Processing Record 7 of Set 11 | hami
# Processing Record 8 of Set 11 | puerto madryn
# Processing Record 9 of Set 11 | paramonga
# Processing Record 10 of Set 11 | dakoro
# Processing Record 11 of Set 11 | aripuana
# Processing Record 12 of Set 11 | lithgow
# Processing Record 13 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 14 of Set 11 | nokaneng
# Processing Record 15 of Set 11 | mount isa
# Processing Record 16 of Set 11 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 11 | vanavara
# Processing Record 18 of Set 11 | sydney
# Processing Record 19 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 20 of Set 11 | buckeye
# Processing Record 21 of Set 11 | nampula
# Processing Record 22 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 23 of Set 11 | kathu
# Processing Record 24 of Set 11 | nouadhibou
# Processing Record 25 of Set 11 | khasan
# Processing Record 26 of Set 11 | saint-pierre
# Processing Record 27 of Set 11 | cabo san lucas
# Processing Record 28 of Set 11 | jaciara
# Processing Record 29 of Set 11 | chissamba
# Processing Record 30 of Set 11 | college
# Processing Record 31 of Set 11 | cooma
# Processing Record 32 of Set 11 | presidencia roque saenz pena
# Processing Record 33 of Set 11 | esna
# Processing Record 34 of Set 11 | wasilla
# Processing Record 35 of Set 11 | konin
# Processing Record 36 of Set 11 | chazuta
# Processing Record 37 of Set 11 | beipiao
# Processing Record 38 of Set 11 | suleja
# Processing Record 39 of Set 11 | gezing
# Processing Record 40 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 11 | pak phanang
# Processing Record 42 of Set 11 | nuuk
# Processing Record 43 of Set 11 | ambon
# Processing Record 44 of Set 11 | bologoye
# Processing Record 45 of Set 11 | djambala
# Processing Record 46 of Set 11 | mulchen
# Processing Record 47 of Set 11 | jinchang
# Processing Record 48 of Set 11 | concordia
# Processing Record 49 of Set 11 | caratinga
# Processing Record 50 of Set 11 | nagato
# Processing Record 1 of Set 12 | alice springs
# Processing Record 2 of Set 12 | general roca
# Processing Record 3 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 4 of Set 12 | santa maria
# Processing Record 5 of Set 12 | abu samrah
# Processing Record 6 of Set 12 | digras
# Processing Record 7 of Set 12 | eureka
# Processing Record 8 of Set 12 | shubarshi
# Processing Record 9 of Set 12 | roswell
# Processing Record 10 of Set 12 | torata
# Processing Record 11 of Set 12 | brest
# Processing Record 12 of Set 12 | luwuk
# Processing Record 13 of Set 12 | acari
# Processing Record 14 of Set 12 | goderich
# Processing Record 15 of Set 12 | huangpi
# Processing Record 16 of Set 12 | shirgaon
# Processing Record 17 of Set 12 | matsanga
# City not found. Skipping...
# Processing Record 18 of Set 12 | vichuga
# Processing Record 19 of Set 12 | serenje
# Processing Record 20 of Set 12 | veseloyarsk
# Processing Record 21 of Set 12 | cockburn town
# Processing Record 22 of Set 12 | atar
# Processing Record 23 of Set 12 | gamba
# Processing Record 24 of Set 12 | bonthe
# Processing Record 25 of Set 12 | almenara
# Processing Record 26 of Set 12 | ballina
# Processing Record 27 of Set 12 | celestun
# Processing Record 28 of Set 12 | cabatuan
# Processing Record 29 of Set 12 | santana do livramento
# Processing Record 30 of Set 12 | perth
# Processing Record 31 of Set 12 | tateyama
# Processing Record 32 of Set 12 | souillac
# Processing Record 33 of Set 12 | cherskiy
# Processing Record 34 of Set 12 | svetlaya
# Processing Record 35 of Set 12 | luanda
# Processing Record 36 of Set 12 | morada nova
# Processing Record 37 of Set 12 | parana
# Processing Record 38 of Set 12 | okhotsk
# Processing Record 39 of Set 12 | bankura
# Processing Record 40 of Set 12 | kampong chhnang
# Processing Record 41 of Set 12 | andenes
# Processing Record 42 of Set 12 | kolo
# Processing Record 43 of Set 12 | ishigaki
# Processing Record 44 of Set 12 | peniche
# Processing Record 45 of Set 12 | mayya
# Processing Record 46 of Set 12 | tommot
# Processing Record 47 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 48 of Set 12 | jalu
# Processing Record 49 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 12 | tibati
# Processing Record 1 of Set 13 | yeppoon
# Processing Record 2 of Set 13 | yulara
# Processing Record 3 of Set 13 | bosaso
# Processing Record 4 of Set 13 | waipawa
# Processing Record 5 of Set 13 | ulaangom
# Processing Record 6 of Set 13 | karratha
# Processing Record 7 of Set 13 | santa maria da vitoria
# Processing Record 8 of Set 13 | mumford
# Processing Record 9 of Set 13 | ust-barguzin
# Processing Record 10 of Set 13 | wakkanai
# Processing Record 11 of Set 13 | yarada
# Processing Record 12 of Set 13 | malakal
# Processing Record 13 of Set 13 | skierniewice
# Processing Record 14 of Set 13 | outjo
# Processing Record 15 of Set 13 | kostroma
# Processing Record 16 of Set 13 | tortoli
# Processing Record 17 of Set 13 | teluknaga
# Processing Record 18 of Set 13 | briancon
# Processing Record 19 of Set 13 | hazorasp
# Processing Record 20 of Set 13 | griffith
# Processing Record 21 of Set 13 | sapa
# Processing Record 22 of Set 13 | lahad datu
# Processing Record 23 of Set 13 | kajaani
# Processing Record 24 of Set 13 | mitu
# Processing Record 25 of Set 13 | karakol
# Processing Record 26 of Set 13 | paamiut
# Processing Record 27 of Set 13 | pastavy
# Processing Record 28 of Set 13 | noumea
# Processing Record 29 of Set 13 | beloha
# Processing Record 30 of Set 13 | barberton
# Processing Record 31 of Set 13 | mucuri
# Processing Record 32 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 33 of Set 13 | muros
# Processing Record 34 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 13 | coihaique
# Processing Record 36 of Set 13 | palafrugell
# Processing Record 37 of Set 13 | maragogi
# Processing Record 38 of Set 13 | hvide sande
# Processing Record 39 of Set 13 | chifeng
# Processing Record 40 of Set 13 | riacho de santana
# Processing Record 41 of Set 13 | fallon
# Processing Record 42 of Set 13 | sitio novo do tocantins
# Processing Record 43 of Set 13 | lesogorskiy
# Processing Record 44 of Set 13 | tulagi
# Processing Record 45 of Set 13 | kalomo
# City not found. Skipping...
# Processing Record 46 of Set 13 | haverfordwest
# Processing Record 47 of Set 13 | shieli
# Processing Record 48 of Set 13 | katokhi
# City not found. Skipping...
# Processing Record 49 of Set 13 | quisqueya
# Processing Record 50 of Set 13 | namwala
# Processing Record 1 of Set 14 | fukue
# Processing Record 2 of Set 14 | marau
# Processing Record 3 of Set 14 | maryborough
# Processing Record 4 of Set 14 | mitsamiouli
# Processing Record 5 of Set 14 | lushunkou
# City not found. Skipping...
# Processing Record 6 of Set 14 | miandrivazo
# Processing Record 7 of Set 14 | looc
# Processing Record 8 of Set 14 | avera
# Processing Record 9 of Set 14 | fairfield
# Processing Record 10 of Set 14 | amazar
# Processing Record 11 of Set 14 | salalah
# Processing Record 12 of Set 14 | aasiaat
# Processing Record 13 of Set 14 | gairo
# Processing Record 14 of Set 14 | saint anthony
# Processing Record 15 of Set 14 | ballitoville
# Processing Record 16 of Set 14 | labytnangi
# Processing Record 17 of Set 14 | sedhiou
# Processing Record 18 of Set 14 | ambatofinandrahana
# Processing Record 19 of Set 14 | rathdrum
# Processing Record 20 of Set 14 | corvallis
# Processing Record 21 of Set 14 | abu dhabi
# Processing Record 22 of Set 14 | batagay
# Processing Record 23 of Set 14 | prince george
# Processing Record 24 of Set 14 | zabaykalsk
# Processing Record 25 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 26 of Set 14 | west wendover
# Processing Record 27 of Set 14 | mamonovo
# Processing Record 28 of Set 14 | marawi
# Processing Record 29 of Set 14 | berdigestyakh
# Processing Record 30 of Set 14 | prince rupert
# Processing Record 31 of Set 14 | sivaki
# Processing Record 32 of Set 14 | korem
# Processing Record 33 of Set 14 | san marino
# Processing Record 34 of Set 14 | svetlyy
# Processing Record 35 of Set 14 | ahtopol
# Processing Record 36 of Set 14 | haapiti
# Processing Record 37 of Set 14 | pangai
# Processing Record 38 of Set 14 | shirhatti
# Processing Record 39 of Set 14 | abong mbang
# Processing Record 40 of Set 14 | bocanda
# Processing Record 41 of Set 14 | kenai
# Processing Record 42 of Set 14 | enumclaw
# Processing Record 43 of Set 14 | puerto escondido
# Processing Record 44 of Set 14 | rurrenabaque
# Processing Record 45 of Set 14 | mangai
# Processing Record 46 of Set 14 | puri
# Processing Record 47 of Set 14 | bang saphan
# Processing Record 48 of Set 14 | domoni
# Processing Record 49 of Set 14 | kitgum
# Processing Record 50 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 15 | abha
# Processing Record 2 of Set 15 | inirida
# Processing Record 3 of Set 15 | ajaccio
# Processing Record 4 of Set 15 | krupina
# Processing Record 5 of Set 15 | sibolga
# Processing Record 6 of Set 15 | lagos
# Processing Record 7 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 8 of Set 15 | temple
# Processing Record 9 of Set 15 | rapid valley
# Processing Record 10 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 11 of Set 15 | qui nhon
# Processing Record 12 of Set 15 | galle
# Processing Record 13 of Set 15 | kovur
# Processing Record 14 of Set 15 | shubarkuduk
# Processing Record 15 of Set 15 | corinto
# Processing Record 16 of Set 15 | minbu
# Processing Record 17 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 18 of Set 15 | pendleton
# Processing Record 19 of Set 15 | contamana
# Processing Record 20 of Set 15 | darnah
# Processing Record 21 of Set 15 | karanja
# Processing Record 22 of Set 15 | qafsah
# City not found. Skipping...
# Processing Record 23 of Set 15 | lasa
# Processing Record 24 of Set 15 | kapuskasing
# Processing Record 25 of Set 15 | cayenne
# Processing Record 26 of Set 15 | kodinsk
# Processing Record 27 of Set 15 | uhlove
# Processing Record 28 of Set 15 | stornoway
# Processing Record 29 of Set 15 | pathein
# Processing Record 30 of Set 15 | onzaga
# Processing Record 31 of Set 15 | kapit
# Processing Record 32 of Set 15 | caxito
# Processing Record 33 of Set 15 | idah
# Processing Record 34 of Set 15 | leh
# Processing Record 35 of Set 15 | novyy urengoy
# Processing Record 36 of Set 15 | volot
# Processing Record 37 of Set 15 | mackay
# Processing Record 38 of Set 15 | nargana
# Processing Record 39 of Set 15 | portsmouth
# Processing Record 40 of Set 15 | tongliao
# Processing Record 41 of Set 15 | iwanai
# Processing Record 42 of Set 15 | santiago del estero
# Processing Record 43 of Set 15 | moose factory
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Tasiilaq  65.6145  -37.6368     14.00        67          75
# 1   Port Elizabeth -33.9180   25.5701     71.60        73          40
# 2       Bredasdorp -34.5322   20.0403     63.00        83          99
# 3         Hermanus -34.4187   19.2345     63.00        83          91
# 4         Ust-Nera  64.5667  143.2000    -29.24        74          99
# 5         Klaksvik  62.2266   -6.5890     23.00        86         100
# 6  Haines Junction  60.7522 -137.5108      1.40        78          92
# 7      Yellowknife  62.4560 -114.3525     -4.00        77          75
# 8            Bluff -46.6000  168.3333     59.77        74          77
# 9      Sunndalsora  62.6754    8.5515     32.00        93          90
#
#    Wind Speed Country                 Date
# 0        3.53      GL  2021-01-31 22:35:25
# 1       21.85      ZA  2021-01-31 22:33:21
# 2        1.99      ZA  2021-01-31 22:35:26
# 3        1.99      ZA  2021-01-31 22:33:24
# 4        7.40      RU  2021-01-31 22:35:26
# 5        1.14      FO  2021-01-31 22:35:26
# 6        5.75      CA  2021-01-31 22:33:22
# 7        4.61      CA  2021-01-31 22:35:01
# 8        3.27      NZ  2021-01-31 22:30:54
# 9        3.44      NO  2021-01-31 22:35:27

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
