# %%
# Import Dependencies .
import pandas as pd 
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests
import time

# %%
# Create an empty list for weather data.
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bdcd2f4e896bc3ba596f00fee7f607e1

# %%
# Create 2000 random latitude and longitude coordinates 
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(latitudes, longitudes)
coordinates

# %%
# Add coordinates to a list.
coordinates_lst = list(coordinates)

# %%
# Create a list for cities.
cities = []

# Use citipy to find nearest cities using coordinate list.
for coordinate in coordinates_lst:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)

# Count amount of unique cities
len(cities)
# Out:
# 738

# %%
# Loop through all the cities in the list. 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 39 of Set 15 | norilsk
# Processing Record 40 of Set 15 | bredasdorp
# Processing Record 41 of Set 15 | hami
# Processing Record 42 of Set 15 | jamestown
# Processing Record 43 of Set 15 | aldan
# Processing Record 44 of Set 15 | soubre
# Processing Record 45 of Set 15 | rikitea
# Processing Record 46 of Set 15 | georgetown
# Processing Record 47 of Set 15 | castro
# Processing Record 48 of Set 15 | saldanha
# Processing Record 49 of Set 15 | qasigiannguit
# Processing Record 50 of Set 15 | port macquarie
# Processing Record 51 of Set 15 | albany
# Processing Record 52 of Set 15 | samarkand
# Processing Record 53 of Set 15 | dikson
# Processing Record 54 of Set 15 | ibb
# Processing Record 55 of Set 15 | nome
# Processing Record 56 of Set 15 | la ronge
# Processing Record 57 of Set 15 | tura
# Processing Record 58 of Set 15 | aksarka
# Processing Record 59 of Set 15 | puerto ayora
# Processing Record 60 of Set 15 | hilo
# Processing Record 61 of Set 15 | atuona
# Processing Record 62 of Set 15 | thompson
# Processing Record 63 of Set 15 | muros
# Processing Record 64 of Set 15 | port elizabeth
# Processing Record 65 of Set 15 | riyadh
# Processing Record 66 of Set 15 | lethem
# Processing Record 67 of Set 15 | luderitz
# Processing Record 68 of Set 15 | bluff
# Processing Record 69 of Set 15 | norman wells
# Processing Record 70 of Set 15 | tabas
# Processing Record 71 of Set 15 | cerete
# Processing Record 72 of Set 15 | attawapiskat
# City not found. Skipping...
# Processing Record 73 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 74 of Set 15 | yellowknife
# Processing Record 75 of Set 15 | praia
# Processing Record 76 of Set 15 | victoria
# Processing Record 77 of Set 15 | dubbo
# Processing Record 78 of Set 15 | punta arenas
# Processing Record 79 of Set 15 | port alfred
# Processing Record 80 of Set 15 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 81 of Set 15 | hobart
# Processing Record 82 of Set 15 | puerto del rosario
# Processing Record 83 of Set 15 | isangel
# Processing Record 84 of Set 15 | hithadhoo
# Processing Record 85 of Set 15 | busselton
# Processing Record 86 of Set 15 | bukachacha
# Processing Record 87 of Set 15 | ilulissat
# Processing Record 88 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 1 of Set 16 | fukue
# Processing Record 2 of Set 16 | villa carlos paz
# Processing Record 3 of Set 16 | mahajanga
# Processing Record 4 of Set 16 | namibe
# Processing Record 5 of Set 16 | lugovoy
# Processing Record 6 of Set 16 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 16 | stege
# Processing Record 8 of Set 16 | vaini
# Processing Record 9 of Set 16 | bengkulu
# Processing Record 10 of Set 16 | murray bridge
# Processing Record 11 of Set 16 | kapaa
# Processing Record 12 of Set 16 | carnarvon
# Processing Record 13 of Set 16 | san jose
# Processing Record 14 of Set 16 | kavieng
# Processing Record 15 of Set 16 | neuquen
# Processing Record 16 of Set 16 | hermanus
# Processing Record 17 of Set 16 | kahului
# Processing Record 18 of Set 16 | krutinka
# Processing Record 19 of Set 16 | a coruna
# Processing Record 20 of Set 16 | nhulunbuy
# Processing Record 21 of Set 16 | kaeo
# Processing Record 22 of Set 16 | srednekolymsk
# Processing Record 23 of Set 16 | san patricio
# Processing Record 24 of Set 16 | sao joao da barra
# Processing Record 25 of Set 16 | douentza
# Processing Record 26 of Set 16 | cabo san lucas
# Processing Record 27 of Set 16 | kampene
# Processing Record 28 of Set 16 | barrow
# Processing Record 29 of Set 16 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 16 | longyearbyen
# Processing Record 31 of Set 16 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 16 | lorengau
# Processing Record 33 of Set 16 | utrecht
# Processing Record 34 of Set 16 | kununurra
# Processing Record 35 of Set 16 | sal rei
# Processing Record 36 of Set 16 | khatanga
# Processing Record 37 of Set 16 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 16 | mandalgovi
# Processing Record 39 of Set 16 | astana
# Processing Record 40 of Set 16 | klaksvik
# Processing Record 41 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 16 | matara
# Processing Record 43 of Set 16 | vila velha
# Processing Record 44 of Set 16 | mahadday weyne
# City not found. Skipping...
# Processing Record 45 of Set 16 | vila franca do campo
# Processing Record 46 of Set 16 | ushuaia
# Processing Record 47 of Set 16 | elizabethton
# Processing Record 48 of Set 16 | sumbawa
# City not found. Skipping...
# Processing Record 49 of Set 16 | bathsheba
# Processing Record 50 of Set 16 | tuktoyaktuk
# Processing Record 1 of Set 17 | saint andrews
# Processing Record 2 of Set 17 | grand-santi
# Processing Record 3 of Set 17 | luwuk
# Processing Record 4 of Set 17 | portland
# Processing Record 5 of Set 17 | cayenne
# Processing Record 6 of Set 17 | khorixas
# Processing Record 7 of Set 17 | mar del plata
# Processing Record 8 of Set 17 | hasaki
# Processing Record 9 of Set 17 | namangan
# Processing Record 10 of Set 17 | provideniya
# Processing Record 11 of Set 17 | okhotsk
# Processing Record 12 of Set 17 | half moon bay
# Processing Record 13 of Set 17 | kalga
# Processing Record 14 of Set 17 | madimba
# Processing Record 15 of Set 17 | olinda
# Processing Record 16 of Set 17 | punta alta
# Processing Record 17 of Set 17 | palmas
# Processing Record 18 of Set 17 | leningradskiy
# Processing Record 19 of Set 17 | arman
# Processing Record 20 of Set 17 | cuamba
# Processing Record 21 of Set 17 | new norfolk
# Processing Record 22 of Set 17 | yudong
# Processing Record 23 of Set 17 | qandala
# Processing Record 24 of Set 17 | adrar
# Processing Record 25 of Set 17 | lompoc
# Processing Record 26 of Set 17 | ushtobe
# Processing Record 27 of Set 17 | khandbari
# Processing Record 28 of Set 17 | penapolis
# Processing Record 29 of Set 17 | yumen
# Processing Record 30 of Set 17 | comodoro rivadavia
# Processing Record 31 of Set 17 | rock springs
# Processing Record 32 of Set 17 | bosaso
# Processing Record 33 of Set 17 | cape town
# Processing Record 34 of Set 17 | gemena
# Processing Record 35 of Set 17 | codrington
# Processing Record 36 of Set 17 | correntina
# Processing Record 37 of Set 17 | touros
# Processing Record 38 of Set 17 | tuggurt
# City not found. Skipping...
# Processing Record 39 of Set 17 | nikolskoye
# Processing Record 40 of Set 17 | general roca
# Processing Record 41 of Set 17 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 17 | omsukchan
# Processing Record 43 of Set 17 | saint-philippe
# Processing Record 44 of Set 17 | miedzyrzecz
# Processing Record 45 of Set 17 | upernavik
# Processing Record 46 of Set 17 | pacific grove
# Processing Record 47 of Set 17 | along
# Processing Record 48 of Set 17 | date
# Processing Record 49 of Set 17 | necochea
# Processing Record 50 of Set 17 | ancud
# Processing Record 1 of Set 18 | salinopolis
# Processing Record 2 of Set 18 | tokmak
# Processing Record 3 of Set 18 | havre-saint-pierre
# Processing Record 4 of Set 18 | lagoa
# Processing Record 5 of Set 18 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 18 | guarapari
# Processing Record 7 of Set 18 | chokwe
# Processing Record 8 of Set 18 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 18 | methala
# Processing Record 10 of Set 18 | obo
# Processing Record 11 of Set 18 | torbay
# Processing Record 12 of Set 18 | saskylakh
# Processing Record 13 of Set 18 | ginda
# Processing Record 14 of Set 18 | east london
# Processing Record 15 of Set 18 | port-gentil
# Processing Record 16 of Set 18 | sai buri
# Processing Record 17 of Set 18 | fortuna
# Processing Record 18 of Set 18 | mayumba
# Processing Record 19 of Set 18 | auki
# Processing Record 20 of Set 18 | yinchuan
# Processing Record 21 of Set 18 | arraial do cabo
# Processing Record 22 of Set 18 | atar
# Processing Record 23 of Set 18 | araouane
# Processing Record 24 of Set 18 | jogindarnagar
# Processing Record 25 of Set 18 | buritizeiro
# Processing Record 26 of Set 18 | san cristobal
# Processing Record 27 of Set 18 | hue
# Processing Record 28 of Set 18 | ust-kuyga
# Processing Record 29 of Set 18 | eureka
# Processing Record 30 of Set 18 | bagotville
# Processing Record 31 of Set 18 | severo-kurilsk
# Processing Record 32 of Set 18 | jaru
# Processing Record 33 of Set 18 | galgani
# City not found. Skipping...
# Processing Record 34 of Set 18 | tilichiki
# Processing Record 35 of Set 18 | tlahualilo
# City not found. Skipping...
# Processing Record 36 of Set 18 | cervo
# Processing Record 37 of Set 18 | guerrero negro
# Processing Record 38 of Set 18 | avarua
# Processing Record 39 of Set 18 | vila do maio
# Processing Record 40 of Set 18 | mao
# Processing Record 41 of Set 18 | kodiak
# Processing Record 42 of Set 18 | manggar
# Processing Record 43 of Set 18 | faya
# Processing Record 44 of Set 18 | chuy
# Processing Record 45 of Set 18 | mingaora
# Processing Record 46 of Set 18 | natal
# Processing Record 47 of Set 18 | sorland
# Processing Record 48 of Set 18 | lebu
# Processing Record 49 of Set 18 | kutum
# Processing Record 50 of Set 18 | blackwater
# Processing Record 1 of Set 19 | shache
# Processing Record 2 of Set 19 | bambous virieux
# Processing Record 3 of Set 19 | baherden
# Processing Record 4 of Set 19 | mweka
# Processing Record 5 of Set 19 | qaanaaq
# Processing Record 6 of Set 19 | sundsvall
# Processing Record 7 of Set 19 | rio gallegos
# Processing Record 8 of Set 19 | fayaoue
# Processing Record 9 of Set 19 | moerai
# Processing Record 10 of Set 19 | tukrah
# Processing Record 11 of Set 19 | chernoyerkovskaya
# Processing Record 12 of Set 19 | yulara
# Processing Record 13 of Set 19 | noumea
# Processing Record 14 of Set 19 | sao filipe
# Processing Record 15 of Set 19 | yeppoon
# Processing Record 16 of Set 19 | homer
# Processing Record 17 of Set 19 | corinto
# Processing Record 18 of Set 19 | grindavik
# Processing Record 19 of Set 19 | ostrovnoy
# Processing Record 20 of Set 19 | nantucket
# Processing Record 21 of Set 19 | narsaq
# Processing Record 22 of Set 19 | umm lajj
# Processing Record 23 of Set 19 | saint-pierre
# Processing Record 24 of Set 19 | airai
# Processing Record 25 of Set 19 | blackfoot
# Processing Record 26 of Set 19 | preobrazheniye
# Processing Record 27 of Set 19 | ekhabi
# Processing Record 28 of Set 19 | hambantota
# Processing Record 29 of Set 19 | lakselv
# Processing Record 30 of Set 19 | impfondo
# Processing Record 31 of Set 19 | constitucion
# Processing Record 32 of Set 19 | macclesfield
# Processing Record 33 of Set 19 | pyapon
# Processing Record 34 of Set 19 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 19 | pecos
# Processing Record 36 of Set 19 | yendi
# Processing Record 37 of Set 19 | mataura
# Processing Record 38 of Set 19 | emerald
# Processing Record 39 of Set 19 | nerchinskiy zavod
# Processing Record 40 of Set 19 | mount vernon
# Processing Record 41 of Set 19 | cam pha
# City not found. Skipping...
# Processing Record 42 of Set 19 | poum
# Processing Record 43 of Set 19 | harper
# Processing Record 44 of Set 19 | terra santa
# Processing Record 45 of Set 19 | rawson
# Processing Record 46 of Set 19 | moanda
# Processing Record 47 of Set 19 | kaitangata
# Processing Record 48 of Set 19 | asau
# Processing Record 49 of Set 19 | takoradi
# Processing Record 50 of Set 19 | locri
# Processing Record 1 of Set 20 | ponta do sol
# Processing Record 2 of Set 20 | yar-sale
# Processing Record 3 of Set 20 | dingle
# Processing Record 4 of Set 20 | tasiilaq
# Processing Record 5 of Set 20 | alihe
# Processing Record 6 of Set 20 | waipawa
# Processing Record 7 of Set 20 | tutoia
# Processing Record 8 of Set 20 | bilibino
# Processing Record 9 of Set 20 | rincon
# Processing Record 10 of Set 20 | chokurdakh
# Processing Record 11 of Set 20 | koulikoro
# Processing Record 12 of Set 20 | sinegorye
# Processing Record 13 of Set 20 | amnat charoen
# Processing Record 14 of Set 20 | kinlochleven
# Processing Record 15 of Set 20 | batticaloa
# Processing Record 16 of Set 20 | maneadero
# Processing Record 17 of Set 20 | virovitica
# Processing Record 18 of Set 20 | kruisfontein
# Processing Record 19 of Set 20 | cabra
# Processing Record 20 of Set 20 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 20 | tigil
# Processing Record 22 of Set 20 | leh
# Processing Record 23 of Set 20 | burnie
# Processing Record 24 of Set 20 | tumalaytay
# Processing Record 25 of Set 20 | shiyan
# Processing Record 26 of Set 20 | greensburg
# Processing Record 27 of Set 20 | tallahassee
# Processing Record 28 of Set 20 | bulawayo
# Processing Record 29 of Set 20 | baghdad
# Processing Record 30 of Set 20 | warwick
# Processing Record 31 of Set 20 | cidreira
# Processing Record 32 of Set 20 | mahebourg
# Processing Record 33 of Set 20 | geraldton
# Processing Record 34 of Set 20 | kupang
# Processing Record 35 of Set 20 | barpeta
# Processing Record 36 of Set 20 | pangnirtung
# Processing Record 37 of Set 20 | lae
# Processing Record 38 of Set 20 | camacha
# Processing Record 39 of Set 20 | paradwip
# City not found. Skipping...
# Processing Record 40 of Set 20 | talnakh
# Processing Record 41 of Set 20 | sakaiminato
# Processing Record 42 of Set 20 | buta
# Processing Record 43 of Set 20 | mangai
# Processing Record 44 of Set 20 | sept-iles
# Processing Record 45 of Set 20 | alice springs
# Processing Record 46 of Set 20 | dina
# Processing Record 47 of Set 20 | uglegorskiy
# Processing Record 48 of Set 20 | caravelas
# Processing Record 49 of Set 20 | namatanai
# Processing Record 50 of Set 20 | broken hill
# Processing Record 1 of Set 21 | manoel urbano
# Processing Record 2 of Set 21 | gat
# Processing Record 3 of Set 21 | fernandina beach
# Processing Record 4 of Set 21 | belle glade
# Processing Record 5 of Set 21 | patrocinio
# Processing Record 6 of Set 21 | sawakin
# Processing Record 7 of Set 21 | iguatemi
# Processing Record 8 of Set 21 | qabis
# City not found. Skipping...
# Processing Record 9 of Set 21 | samarai
# Processing Record 10 of Set 21 | sitka
# Processing Record 11 of Set 21 | mount pleasant
# Processing Record 12 of Set 21 | okato
# Processing Record 13 of Set 21 | north bend
# Processing Record 14 of Set 21 | kaseda
# Processing Record 15 of Set 21 | grand centre
# City not found. Skipping...
# Processing Record 16 of Set 21 | belmonte
# Processing Record 17 of Set 21 | los llanos de aridane
# Processing Record 18 of Set 21 | kajaani
# Processing Record 19 of Set 21 | ballina
# Processing Record 20 of Set 21 | andenes
# Processing Record 21 of Set 21 | xuddur
# Processing Record 22 of Set 21 | fare
# Processing Record 23 of Set 21 | okha
# Processing Record 24 of Set 21 | acaponeta
# Processing Record 25 of Set 21 | hutchinson
# Processing Record 26 of Set 21 | clyde river
# Processing Record 27 of Set 21 | tuatapere
# Processing Record 28 of Set 21 | keti bandar
# Processing Record 29 of Set 21 | huimilpan
# Processing Record 30 of Set 21 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 21 | pevek
# Processing Record 32 of Set 21 | imbituba
# Processing Record 33 of Set 21 | chake chake
# Processing Record 34 of Set 21 | okulovka
# Processing Record 35 of Set 21 | tarakan
# Processing Record 36 of Set 21 | port hedland
# Processing Record 37 of Set 21 | hailey
# Processing Record 38 of Set 21 | aklavik
# Processing Record 39 of Set 21 | kasongo
# Processing Record 40 of Set 21 | souillac
# Processing Record 41 of Set 21 | lata
# Processing Record 42 of Set 21 | matsanga
# City not found. Skipping...
# Processing Record 43 of Set 21 | saint-augustin
# Processing Record 44 of Set 21 | la plata
# Processing Record 45 of Set 21 | santa rosa
# Processing Record 46 of Set 21 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 21 | sarnia
# Processing Record 48 of Set 21 | guangshui
# Processing Record 49 of Set 21 | disa
# Processing Record 50 of Set 21 | brae
# Processing Record 1 of Set 22 | bonavista
# Processing Record 2 of Set 22 | macamic
# Processing Record 3 of Set 22 | vesyegonsk
# Processing Record 4 of Set 22 | san matias
# Processing Record 5 of Set 22 | laubach
# Processing Record 6 of Set 22 | vicuna
# Processing Record 7 of Set 22 | mangrol
# Processing Record 8 of Set 22 | axim
# Processing Record 9 of Set 22 | deputatskiy
# Processing Record 10 of Set 22 | sofiysk
# City not found. Skipping...
# Processing Record 11 of Set 22 | quthing
# Processing Record 12 of Set 22 | acajutla
# Processing Record 13 of Set 22 | dalvik
# Processing Record 14 of Set 22 | mehamn
# Processing Record 15 of Set 22 | berlevag
# Processing Record 16 of Set 22 | berdigestyakh
# Processing Record 17 of Set 22 | hofn
# Processing Record 18 of Set 22 | ribeira grande
# Processing Record 19 of Set 22 | bandarbeyla
# Processing Record 20 of Set 22 | makakilo city
# Processing Record 21 of Set 22 | nouadhibou
# Processing Record 22 of Set 22 | viedma
# Processing Record 23 of Set 22 | sibiti
# Processing Record 24 of Set 22 | beringovskiy
# Processing Record 25 of Set 22 | odessa
# Processing Record 26 of Set 22 | pychas
# Processing Record 27 of Set 22 | mareeba
# Processing Record 28 of Set 22 | saint george
# Processing Record 29 of Set 22 | rocha
# Processing Record 30 of Set 22 | baiyin
# Processing Record 31 of Set 22 | saint-francois
# Processing Record 32 of Set 22 | daokou
# Processing Record 33 of Set 22 | cherskiy
# Processing Record 34 of Set 22 | ulaanbaatar
# Processing Record 35 of Set 22 | bethel
# Processing Record 36 of Set 22 | lavrentiya
# Processing Record 37 of Set 22 | katsuura
# Processing Record 38 of Set 22 | rodrigues alves
# Processing Record 39 of Set 22 | liverpool
# Processing Record 40 of Set 22 | taoudenni
# Processing Record 41 of Set 22 | guozhen
# Processing Record 42 of Set 22 | loudi
# Processing Record 43 of Set 22 | prince rupert
# Processing Record 44 of Set 22 | karauzyak
# City not found. Skipping...
# Processing Record 45 of Set 22 | kuppam
# Processing Record 46 of Set 22 | praia da vitoria
# Processing Record 47 of Set 22 | goiania
# Processing Record 48 of Set 22 | macaboboni
# City not found. Skipping...
# Processing Record 49 of Set 22 | butaritari
# Processing Record 50 of Set 22 | rexburg
# Processing Record 1 of Set 23 | luganville
# Processing Record 2 of Set 23 | gunjur
# Processing Record 3 of Set 23 | aflu
# City not found. Skipping...
# Processing Record 4 of Set 23 | nanortalik
# Processing Record 5 of Set 23 | kushalgarh
# Processing Record 6 of Set 23 | marsa matruh
# Processing Record 7 of Set 23 | cairns
# Processing Record 8 of Set 23 | sainte-suzanne
# Processing Record 9 of Set 23 | porto santo
# Processing Record 10 of Set 23 | belyy yar
# Processing Record 11 of Set 23 | pedernales
# Processing Record 12 of Set 23 | san jeronimo
# Processing Record 13 of Set 23 | abnub
# Processing Record 14 of Set 23 | chalmette
# Processing Record 15 of Set 23 | acarau
# Processing Record 16 of Set 23 | jieshi
# Processing Record 17 of Set 23 | wattegama
# Processing Record 18 of Set 23 | ngunguru
# Processing Record 19 of Set 23 | broome
# Processing Record 20 of Set 23 | te anau
# Processing Record 21 of Set 23 | vestmannaeyjar
# Processing Record 22 of Set 23 | lisakovsk
# Processing Record 23 of Set 23 | carutapera
# Processing Record 24 of Set 23 | tsienyane
# City not found. Skipping...
# Processing Record 25 of Set 23 | kautokeino
# Processing Record 26 of Set 23 | zaozerne
# Processing Record 27 of Set 23 | tessalit
# Processing Record 28 of Set 23 | kungurtug
# Processing Record 29 of Set 23 | mangan
# Processing Record 30 of Set 23 | hirara
# Processing Record 31 of Set 23 | tabou
# Processing Record 32 of Set 23 | tucano
# Processing Record 33 of Set 23 | smoky lake
# Processing Record 34 of Set 23 | yerbogachen
# Processing Record 35 of Set 23 | marienburg
# Processing Record 36 of Set 23 | houlton
# Processing Record 37 of Set 23 | itarema
# Processing Record 38 of Set 23 | hlobyne
# Processing Record 39 of Set 23 | bokspits
# City not found. Skipping...
# Processing Record 40 of Set 23 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 23 | mecca
# Processing Record 42 of Set 23 | westport
# Processing Record 43 of Set 23 | kharp
# Processing Record 44 of Set 23 | chibuto
# Processing Record 45 of Set 23 | zhigansk
# Processing Record 46 of Set 23 | alzamay
# Processing Record 47 of Set 23 | tabuk
# Processing Record 48 of Set 23 | kifri
# Processing Record 49 of Set 23 | port-cartier
# Processing Record 50 of Set 23 | maldonado
# Processing Record 1 of Set 24 | rawannawi
# City not found. Skipping...
# Processing Record 2 of Set 24 | payo
# Processing Record 3 of Set 24 | havelock
# Processing Record 4 of Set 24 | roma
# Processing Record 5 of Set 24 | cap malheureux
# Processing Record 6 of Set 24 | veraval
# Processing Record 7 of Set 24 | pervomayskoye
# Processing Record 8 of Set 24 | wagar
# Processing Record 9 of Set 24 | dharchula
# Processing Record 10 of Set 24 | lazaro cardenas
# Processing Record 11 of Set 24 | kloulklubed
# Processing Record 12 of Set 24 | tiksi
# Processing Record 13 of Set 24 | collie
# Processing Record 14 of Set 24 | ahipara
# Processing Record 15 of Set 24 | gamboula
# Processing Record 16 of Set 24 | kampot
# Processing Record 17 of Set 24 | vanderhoof
# Processing Record 18 of Set 24 | racova
# Processing Record 19 of Set 24 | lukovetskiy
# Processing Record 20 of Set 24 | ibipeba
# Processing Record 21 of Set 24 | azimur
# City not found. Skipping...
# Processing Record 22 of Set 24 | fairlie
# Processing Record 23 of Set 24 | nemuro
# Processing Record 24 of Set 24 | dzhusaly
# City not found. Skipping...
# Processing Record 25 of Set 24 | la grande
# Processing Record 26 of Set 24 | winnemucca
# Processing Record 27 of Set 24 | boueni
# Processing Record 28 of Set 24 | cape elizabeth
# City not found. Skipping...
# Processing Record 29 of Set 24 | naze
# Processing Record 30 of Set 24 | edd
# Processing Record 31 of Set 24 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 24 | yungay
# Processing Record 33 of Set 24 | houma
# Processing Record 34 of Set 24 | mount gambier
# Processing Record 35 of Set 24 | bria
# Processing Record 36 of Set 24 | aripuana
# Processing Record 37 of Set 24 | the valley
# Processing Record 38 of Set 24 | lamu
# Processing Record 39 of Set 24 | sciacca
# Processing Record 40 of Set 24 | bereda
# Processing Record 41 of Set 24 | hualmay
# Processing Record 42 of Set 24 | astoria
# Processing Record 43 of Set 24 | xiongyue
# Processing Record 44 of Set 24 | rio grande
# Processing Record 45 of Set 24 | yuzhno-sukhokumsk
# Processing Record 46 of Set 24 | roald
# Processing Record 47 of Set 24 | alofi
# Processing Record 48 of Set 24 | college
# Processing Record 49 of Set 24 | takanabe
# Processing Record 50 of Set 24 | esperance
# Processing Record 1 of Set 25 | blacksburg
# Processing Record 2 of Set 25 | parrita
# Processing Record 3 of Set 25 | porto walter
# Processing Record 4 of Set 25 | laguna
# Processing Record 5 of Set 25 | victor harbor
# Processing Record 6 of Set 25 | luan
# Processing Record 7 of Set 25 | xining
# Processing Record 8 of Set 25 | cranbrook
# Processing Record 9 of Set 25 | pisco
# Processing Record 10 of Set 25 | port moresby
# Processing Record 11 of Set 25 | ucluelet
# Processing Record 12 of Set 25 | kysyl-syr
# Processing Record 13 of Set 25 | udachnyy
# Processing Record 14 of Set 25 | yanam
# Processing Record 15 of Set 25 | warmbad
# Processing Record 16 of Set 25 | asmara
# Processing Record 17 of Set 25 | garlasco
# Processing Record 18 of Set 25 | acapulco
# Processing Record 19 of Set 25 | nelson
# Processing Record 20 of Set 25 | batagay
# Processing Record 21 of Set 25 | marsh harbour
# Processing Record 22 of Set 25 | waddan
# Processing Record 23 of Set 25 | placido de castro
# Processing Record 24 of Set 25 | fairbanks
# Processing Record 25 of Set 25 | gamba
# Processing Record 26 of Set 25 | assiniboia
# Processing Record 27 of Set 25 | hastings
# Processing Record 28 of Set 25 | luanda
# Processing Record 29 of Set 25 | chifeng
# Processing Record 30 of Set 25 | skelleftea
# Processing Record 31 of Set 25 | labuhan
# Processing Record 32 of Set 25 | reconquista
# Processing Record 33 of Set 25 | dhidhdhoo
# Processing Record 34 of Set 25 | gorom-gorom
# Processing Record 35 of Set 25 | merauke
# Processing Record 36 of Set 25 | skiros
# City not found. Skipping...
# Processing Record 37 of Set 25 | mogadishu
# Processing Record 38 of Set 25 | willowmore
# Processing Record 39 of Set 25 | muli
# Processing Record 40 of Set 25 | ponta delgada
# Processing Record 41 of Set 25 | obluche
# City not found. Skipping...
# Processing Record 42 of Set 25 | rolim de moura
# City not found. Skipping...
# Processing Record 43 of Set 25 | bemidji
# Processing Record 44 of Set 25 | horasan
# Processing Record 45 of Set 25 | golden
# Processing Record 46 of Set 25 | vila
# Processing Record 47 of Set 25 | mahon
# Processing Record 48 of Set 25 | dinsor
# City not found. Skipping...
# Processing Record 49 of Set 25 | marystown
# Processing Record 50 of Set 25 | tombouctou
# Processing Record 1 of Set 26 | exu
# Processing Record 2 of Set 26 | maragogi
# Processing Record 3 of Set 26 | tolaga bay
# Processing Record 4 of Set 26 | huangmei
# Processing Record 5 of Set 26 | ibra
# Processing Record 6 of Set 26 | villarrobledo
# Processing Record 7 of Set 26 | rajapur
# Processing Record 8 of Set 26 | palu
# Processing Record 9 of Set 26 | preston
# Processing Record 10 of Set 26 | san quintin
# Processing Record 11 of Set 26 | nianzishan
# Processing Record 12 of Set 26 | flinders
# Processing Record 13 of Set 26 | oktyabrskoye
# Processing Record 14 of Set 26 | pervomayskiy
# Processing Record 15 of Set 26 | quelimane
# Processing Record 16 of Set 26 | polovinnoye
# Processing Record 17 of Set 26 | puerto escondido
# Processing Record 18 of Set 26 | ginir
# Processing Record 19 of Set 26 | gizo
# Processing Record 20 of Set 26 | japura
# Processing Record 21 of Set 26 | qinhuangdao
# Processing Record 22 of Set 26 | tautira
# Processing Record 23 of Set 26 | ahuimanu
# Processing Record 24 of Set 26 | sao geraldo do araguaia
# Processing Record 25 of Set 26 | chapais
# Processing Record 26 of Set 26 | muhos
# Processing Record 27 of Set 26 | troitsko-pechorsk
# Processing Record 28 of Set 26 | bichena
# Processing Record 29 of Set 26 | helong
# Processing Record 30 of Set 26 | stephenville
# Processing Record 31 of Set 26 | springbok
# Processing Record 32 of Set 26 | benguela
# Processing Record 33 of Set 26 | melioratorov
# Processing Record 34 of Set 26 | port shepstone
# Processing Record 35 of Set 26 | ketchikan
# Processing Record 36 of Set 26 | vanimo
# Processing Record 37 of Set 26 | dumas
# Processing Record 38 of Set 26 | bulgan
# Processing Record 39 of Set 26 | inta
# Processing Record 40 of Set 26 | sawtell
# Processing Record 41 of Set 26 | husavik
# Processing Record 42 of Set 26 | whitehorse
# Processing Record 43 of Set 26 | ksenyevka
# City not found. Skipping...
# Processing Record 44 of Set 26 | vanavara
# Processing Record 45 of Set 26 | byron bay
# Processing Record 46 of Set 26 | saint-joseph
# Processing Record 47 of Set 26 | bintulu
# Processing Record 48 of Set 26 | la rioja
# Processing Record 49 of Set 26 | wulanhaote
# City not found. Skipping...
# Processing Record 50 of Set 26 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 27 | port hardy
# Processing Record 2 of Set 27 | artyk
# City not found. Skipping...
# Processing Record 3 of Set 27 | banposh
# Processing Record 4 of Set 27 | sinnamary
# Processing Record 5 of Set 27 | sol-iletsk
# Processing Record 6 of Set 27 | lumajang
# Processing Record 7 of Set 27 | jiuquan
# Processing Record 8 of Set 27 | bubaque
# Processing Record 9 of Set 27 | mulege
# Processing Record 10 of Set 27 | glendive
# Processing Record 11 of Set 27 | baraya
# Processing Record 12 of Set 27 | frutigen
# Processing Record 13 of Set 27 | domoni
# Processing Record 14 of Set 27 | tondano
# Processing Record 15 of Set 27 | balakhta
# Processing Record 16 of Set 27 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 27 | beawar
# Processing Record 18 of Set 27 | dukat
# Processing Record 19 of Set 27 | ladovskaya balka
# Processing Record 20 of Set 27 | san andres
# Processing Record 21 of Set 27 | kuching
# Processing Record 22 of Set 27 | anadyr
# Processing Record 23 of Set 27 | ciechocinek
# Processing Record 24 of Set 27 | salalah
# Processing Record 25 of Set 27 | hervey bay
# Processing Record 26 of Set 27 | svetlyy
# Processing Record 27 of Set 27 | iqaluit
# Processing Record 28 of Set 27 | anaco
# Processing Record 29 of Set 27 | izyaslav
# Processing Record 30 of Set 27 | kitoy
# Processing Record 31 of Set 27 | murud
# Processing Record 32 of Set 27 | mahenge
# Processing Record 33 of Set 27 | stawell
# Processing Record 34 of Set 27 | karachi
# Processing Record 35 of Set 27 | ayan
# Processing Record 36 of Set 27 | teguldet
# Processing Record 37 of Set 27 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 27 | hay river
# Processing Record 39 of Set 27 | meulaboh
# Processing Record 40 of Set 27 | belen
# Processing Record 41 of Set 27 | dedovichi
# Processing Record 42 of Set 27 | emba
# Processing Record 43 of Set 27 | nishihara
# Processing Record 44 of Set 27 | juba
# Processing Record 45 of Set 27 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 27 | kuala terengganu
# Processing Record 47 of Set 27 | pingliang
# Processing Record 48 of Set 27 | sioux lookout
# Processing Record 49 of Set 27 | mukhen
# Processing Record 50 of Set 27 | jaguaribe
# Processing Record 1 of Set 28 | ciudad bolivar
# Processing Record 2 of Set 28 | ouadda
# Processing Record 3 of Set 28 | ngukurr
# City not found. Skipping...
# Processing Record 4 of Set 28 | santo antonio do ica
# Processing Record 5 of Set 28 | lusambo
# Processing Record 6 of Set 28 | saint-jean-port-joli
# Processing Record 7 of Set 28 | high prairie
# Processing Record 8 of Set 28 | coquimbo
# Processing Record 9 of Set 28 | dunedin
# Processing Record 10 of Set 28 | ixtapa
# Processing Record 11 of Set 28 | auburndale
# Processing Record 12 of Set 28 | moron
# Processing Record 13 of Set 28 | sun prairie
# Processing Record 14 of Set 28 | mayor pablo lagerenza
# Processing Record 15 of Set 28 | oranjemund
# Processing Record 16 of Set 28 | sataua
# City not found. Skipping...
# Processing Record 17 of Set 28 | bambanglipuro
# Processing Record 18 of Set 28 | rapid valley
# Processing Record 19 of Set 28 | mizpe ramon
# City not found. Skipping...
# Processing Record 20 of Set 28 | angoche
# Processing Record 21 of Set 28 | kargasok
# Processing Record 22 of Set 28 | sao gabriel da cachoeira
# Processing Record 23 of Set 28 | eirunepe
# Processing Record 24 of Set 28 | guiratinga
# Processing Record 25 of Set 28 | bur gabo
# City not found. Skipping...
# Processing Record 26 of Set 28 | nata
# Processing Record 27 of Set 28 | calama
# Processing Record 28 of Set 28 | garhi khairo
# Processing Record 29 of Set 28 | kendari
# Processing Record 30 of Set 28 | ahar
# Processing Record 31 of Set 28 | pudukkottai
# Processing Record 32 of Set 28 | florianopolis
# Processing Record 33 of Set 28 | san rafael
# Processing Record 34 of Set 28 | snina
# Processing Record 35 of Set 28 | ust-tsilma
# Processing Record 36 of Set 28 | karkaralinsk
# City not found. Skipping...
# Processing Record 37 of Set 28 | dicabisagan
# Processing Record 38 of Set 28 | santana do livramento
# Processing Record 39 of Set 28 | faanui
# Processing Record 40 of Set 28 | puerto baquerizo moreno
# Processing Record 41 of Set 28 | pouebo
# Processing Record 42 of Set 28 | alyangula
# Processing Record 43 of Set 28 | svetlaya
# Processing Record 44 of Set 28 | olafsvik
# Processing Record 45 of Set 28 | quatre cocos
# Processing Record 46 of Set 28 | sorvag
# City not found. Skipping...
# Processing Record 47 of Set 28 | cefalu
# Processing Record 48 of Set 28 | buariki
# City not found. Skipping...
# Processing Record 49 of Set 28 | gurupi
# Processing Record 50 of Set 28 | nago
# Processing Record 1 of Set 29 | demerval lobao
# Processing Record 2 of Set 29 | korla
# Processing Record 3 of Set 29 | barsi
# Processing Record 4 of Set 29 | velykyy klyuchiv
# Processing Record 5 of Set 29 | villaviciosa
# Processing Record 6 of Set 29 | progreso
# Processing Record 7 of Set 29 | vestmanna
# Processing Record 8 of Set 29 | malanje
# Processing Record 9 of Set 29 | qaqortoq
# Processing Record 10 of Set 29 | leshukonskoye
# Processing Record 11 of Set 29 | chulym
# Processing Record 12 of Set 29 | mga
# Processing Record 13 of Set 29 | santa luzia
# Processing Record 14 of Set 29 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 29 | ust-kulom
# Processing Record 16 of Set 29 | panama city
# Processing Record 17 of Set 29 | lakes entrance
# Processing Record 18 of Set 29 | bayir
# Processing Record 19 of Set 29 | maceio
# Processing Record 20 of Set 29 | wahiawa
# Processing Record 21 of Set 29 | khasan
# Processing Record 22 of Set 29 | hovd
# Processing Record 23 of Set 29 | acari
# Processing Record 24 of Set 29 | meyungs
# City not found. Skipping...
# Processing Record 25 of Set 29 | tooele
# Processing Record 26 of Set 29 | andapa
# Processing Record 27 of Set 29 | monte mor
# Processing Record 28 of Set 29 | cabedelo
# Processing Record 29 of Set 29 | panaba
# Processing Record 30 of Set 29 | rafai
# Processing Record 31 of Set 29 | shimoda
# Processing Record 32 of Set 29 | urumqi
# Processing Record 33 of Set 29 | korfovskiy
# Processing Record 34 of Set 29 | turukhansk
# Processing Record 35 of Set 29 | beloha
# Processing Record 36 of Set 29 | ostersund
# Processing Record 37 of Set 29 | havoysund
# Processing Record 38 of Set 29 | karratha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Norilsk  69.3535   88.2027    -26.07        73          57        8.70
# 1  Bredasdorp -34.5322   20.0403     66.00        91          37        5.01
# 2        Hami  42.8000   93.4500     25.48        79           7        7.27
# 3   Jamestown  42.0970  -79.2353     30.99        74          90       14.97
# 4       Aldan  58.6031  125.3894    -46.95        78         100        1.66
# 5      Soubre   5.7856   -6.6083     87.22        57          50        5.53
# 6     Rikitea -23.1203 -134.9692     78.71        66          11        9.40
# 7  Georgetown   5.4112  100.3354     80.60        83          20        6.91
# 8      Castro -24.7911  -50.0119     73.36        75          98       10.51
# 9    Saldanha -33.0117   17.9442     66.56        89          28        6.31
#
#   Country                 Date
# 0      RU  2021-01-31 18:13:41
# 1      ZA  2021-01-31 18:13:41
# 2      CN  2021-01-31 18:13:42
# 3      US  2021-01-31 18:13:42
# 4      RU  2021-01-31 18:13:42
# 5      CI  2021-01-31 18:13:43
# 6      PF  2021-01-31 18:13:44
# 7      MY  2021-01-31 18:08:59
# 8      BR  2021-01-31 18:10:23
# 9      ZA  2021-01-31 18:08:59

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/cities.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
